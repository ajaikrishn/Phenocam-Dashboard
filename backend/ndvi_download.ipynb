# %%
import os
import json
from config import *
from backend.ndvi_download import *
import geopandas as gpd
from PIL import Image, ImageOps, ImageDraw
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from mpl_toolkits.axes_grid1 import ImageGrid
from datetime import datetime, timedelta
import numpy.ma as ma
from datetime import datetime
import pandas as pd

# %%
ndvi_data_dir = [os.path.join(phenocam_dir,files) for files in os.listdir(phenocam_dir) if files.endswith('.csv')]
output_dir = '/home/ajai-krishna/work/Phenocam_d3/csv_lists'

# %%
ndvi_files = [files for files in ndvi_data_dir]
ndvi_files
# Out:
# ['/home/ajai-krishna/work/Phenocam_d3/Phenocamdata_local/APU_pos_01_2026_01_27_11_21_44.csv',
#  '/home/ajai-krishna/work/Phenocam_d3/Phenocamdata_local/APU_pos_01_2026_01_31_11_21_55.csv',
#  '/home/ajai-krishna/work/Phenocam_d3/Phenocamdata_local/APU_pos_01_2026_02_27_11_31_47.csv',
#  '/home/ajai-krishna/work/Phenocam_d3/Phenocamdata_local/APU_pos_01_2026_02_21_11_11_41.csv',
#  '/home/ajai-krishna/work/Phenocam_d3/Phenocamdata_local/APU_pos_01_2026_02_23_11_31_45.csv']

# %%
save_ndvi_file_lists(ndvi_files, output_dir)
# Out:
# Saved date list to: /home/ajai-krishna/work/Phenocam_d3/csv_lists/ndvi_file_list.json
# Saved file paths to: /home/ajai-krishna/work/Phenocam_d3/csv_lists/ndvi_file_paths.json
