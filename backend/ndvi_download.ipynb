# %%
import os
import json
from config import *
from ndvi_download import *
import geopandas as gpd
from PIL import Image, ImageOps, ImageDraw
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from mpl_toolkits.axes_grid1 import ImageGrid
from datetime import datetime, timedelta
import numpy.ma as ma
from datetime import datetime
import pandas as pd

# %%
ndvi_data_dir = [os.path.join(phenocam_dir,files) for files in os.listdir(phenocam_dir) if files.endswith('.csv')]
output_ndvi_list_dir = os.path.join(BASE_DIR+'csv_lists')

# %%
ndvi_files = [files for files in ndvi_data_dir]
ndvi_files

# %%
save_ndvi_file_lists(ndvi_files, output_ndvi_list_dir)
